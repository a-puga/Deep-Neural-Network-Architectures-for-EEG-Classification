# %%
# %cd /content
# Out:
# /content

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import matplotlib.pyplot as plt
from torchsummary import summary

# %% [markdown]
# ## ShallowConvNet with ReLU Activation Function

# %%
class ShallowConvNet(nn.Module):
    def __init__(self, n_output):
        super(ShallowConvNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 40, kernel_size=(1, 10))
        self.conv2 = nn.Conv2d(40, 40, kernel_size=(22, 1))
        self.batchnorm = nn.BatchNorm2d(40)
        self.activation = nn.ReLU()
        self.avgpool = nn.AvgPool2d(kernel_size=(1, 75), stride=(1, 15))
        self.dropout = nn.Dropout(0.3)
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(480, n_output)

    def forward(self, x):
        x = self.activation(self.batchnorm(self.conv1(x)))
        x = self.activation(self.batchnorm(self.conv2(x)))
        x = self.avgpool(x)
        x = torch.log(torch.clamp(x, min=1e-06))
        x = self.flatten(x)
        x = self.dropout(x)
        x = self.fc(x)
        return x

# %% [markdown]
# ## Data Preparation

# %%
def data_prep(X,y,sub_sample,average,noise,time):
    total_X = None
    total_y = None

    # Trim the data from 1000 to 500 time steps
    X = X[:,:,0:time]
    #print('Shape after trimm:',X.shape)

    # Maxpool the data from 1000 to 500/subsample
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)

    total_X = X_max
    total_y = y
    #print('Shape after maxpool:',total_X.shape)

    # Averaging + noise
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)

    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    #print('Shape after averaging+noise and concatenating:',total_X.shape)

    # Subsampling
    for i in range(sub_sample):
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))

    #print('Shape after subsampling and concatenating:',total_X.shape)
    return total_X,total_y

def to_categorical(y, num_classes):
    """ 1-hot encodes a tensor """
    return np.eye(num_classes, dtype='uint8')[y]

def test_data_prep(X, y, time):

    total_X = None
    total_y = None

    # Trimming the data (sample,22,1000) -> (sample,22,500)
    X = X[:,:,0:time]
    # print('Shape of X after trimming:',X.shape)

    # Maxpooling the data (sample,22,1000) -> (sample,22,500/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, 2), axis=3)

    total_X = X_max
    total_y = y
    # print('Shape of X after maxpooling:',total_X.shape)

    return total_X, total_y

# %%
def load_data(time, debug=False, onehot=True):

## Loading the dataset
    X_test = np.load("X_test.npy")
    y_test = np.load("y_test.npy")
    person_train_valid = np.load("person_train_valid.npy")
    X_train_valid = np.load("X_train_valid.npy")
    y_train_valid = np.load("y_train_valid.npy")
    person_test = np.load("person_test.npy")

    ## Adjusting the labels so that

    # Cue onset left - 0
    # Cue onset right - 1
    # Cue onset foot - 2
    # Cue onset tongue - 3

    y_train_valid -= 769
    y_test -= 769


    ## Random splitting and reshaping the data
    # First generating the training and validation indices using random splitting

    ind_valid = np.random.choice(2115, 375, replace=False)
    ind_train = np.array(list(set(range(2115)).difference(set(ind_valid))))

    # Creating the training and validation sets using the generated indices
    (x_train, x_valid) = X_train_valid[ind_train], X_train_valid[ind_valid]
    (y_train, y_valid) = y_train_valid[ind_train], y_train_valid[ind_valid]


    ## Preprocessing the dataset
    x_train,y_train = data_prep(x_train,y_train,2,2,True,time)
    x_valid,y_valid = data_prep(x_valid,y_valid,2,2,True,time)
    X_test,y_test = test_data_prep(X_test,y_test, time)

    if debug:
        print('Shape of training set:',x_train.shape)
        print('Shape of validation set:',x_valid.shape)
        print('Shape of training labels:',y_train.shape)
        print('Shape of validation labels:',y_valid.shape)
        print('Shape of testing set:',X_test.shape)
        print('Shape of testing labels:',y_test.shape)


    if onehot:
        # Converting the labels to categorical variables for multiclass classification
        y_train = to_categorical(y_train, 4)
        y_valid = to_categorical(y_valid, 4)
        y_test = to_categorical(y_test, 4)
        if debug:
            print('Shape of training labels after categorical conversion:',y_train.shape)
            print('Shape of validation labels after categorical conversion:',y_valid.shape)
            print('Shape of test labels after categorical conversion:',y_test.shape)

    # Adding width of the segment to be 1
    x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
    x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
    x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)
    if debug:
        print('Shape of training set after adding width info:',x_train.shape)
        print('Shape of validation set after adding width info:',x_valid.shape)
        print('Shape of test set after adding width info:',x_test.shape)


    # Reshaping the training and validation dataset
    x_train = np.swapaxes(x_train, 1,3)
    x_train = np.swapaxes(x_train, 2,3)
    x_valid = np.swapaxes(x_valid, 1,3)
    x_valid = np.swapaxes(x_valid, 2,3)
    x_test = np.swapaxes(x_test, 1,3)
    x_test = np.swapaxes(x_test, 2,3)
    if debug:
        print('Shape of training set after dimension reshaping:',x_train.shape)
        print('Shape of validation set after dimension reshaping:',x_valid.shape)
        print('Shape of test set after dimension reshaping:',x_test.shape)



    return x_train, x_valid, x_test, y_train, y_valid, y_test, person_train_valid, person_test

# %% [markdown]
# ## Setting Model Parameters

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.min_validation_loss = float('inf')

    def early_stop(self, validation_loss):
        if validation_loss < self.min_validation_loss:
            self.min_validation_loss = validation_loss
            self.counter = 0
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
epochs = 100
lr = 8e-4

model = ShallowConvNet(n_output=4)
print(model)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)
#optimizer = optim.RMSprop(model.parameters(),lr = lr, momentum = 0.6)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[1,3,5], gamma=0.1)
early_stopper = EarlyStopper(patience=3, min_delta=10)
# Out:
# ShallowConvNet(
#   (conv1): Conv2d(1, 40, kernel_size=(1, 10), stride=(1, 1))
#   (conv2): Conv2d(40, 40, kernel_size=(22, 1), stride=(1, 1))
#   (batchnorm): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (activation): ReLU()
#   (avgpool): AvgPool2d(kernel_size=(1, 75), stride=(1, 15), padding=0)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc): Linear(in_features=480, out_features=4, bias=True)
# )

# %%
def testing(test_loader, model, device):
    model.eval()
    valid_loss = 0
    with torch.no_grad():
        model.cuda(0)
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            n = targets.shape[0]
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            valid_loss += loss.item()
            valid_loss_history.append(valid_loss)
            correct_test = (torch.max(outputs,1)[1]==targets).sum().item()
        test_accuracy = correct_test/n
        valid_loss /= len(valid_loader)
            # print("testing accuracy:",correct/n)
    return test_accuracy, valid_loss

# %% [markdown]
# ## Training

# %%
time = 500
min_loss=1
max_accuracy = 0
x_train, x_valid, x_test, y_train, y_valid, y_test, person_train_valid, person_test = load_data(time=time, debug = True, onehot=False)
device = torch.device("cuda:0")

# Convert numpy arrays to PyTorch tensors
x_train_tensor = torch.tensor(x_train).float()
y_train_tensor = torch.tensor(y_train).long()
x_valid_tensor = torch.tensor(x_valid).float()
y_valid_tensor = torch.tensor(y_valid).long()
x_test_tensor = torch.tensor(x_test).float()
y_test_tensor = torch.tensor(y_test).long()

# Create PyTorch datasets
train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
valid_dataset = TensorDataset(x_valid_tensor, y_valid_tensor)
test_dataset = TensorDataset(x_test_tensor, y_test_tensor)

# Define batch size and create data loaders
batch_size = 128
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

model.cuda(0)
summary(model.cuda(),(1,22,250))

loss_history = []
train_accuracy_history = []
valid_accuracy_history = []
valid_loss_history = []

# Train the model
for epoch in range(epochs):
    train_loss = 0
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        train_loss += loss.item()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    if epoch%1==0:
        n = targets.shape[0]
        correct = (torch.max(outputs,1)[1]==targets).sum().item()
        train_accuracy = correct / n
        train_accuracy_history.append(train_accuracy)

        model.eval()
        valid_loss = 0
        with torch.no_grad():
            model.cuda(0)
            for inputs, targets in valid_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                n = targets.shape[0]
                outputs = model(inputs)
                vloss = criterion(outputs, targets)
                valid_loss += vloss.item()
                if early_stopper.early_stop(valid_loss):
                  break

        correct_test = (torch.max(outputs,1)[1]==targets).sum().item()
        valid_accuracy = correct_test/n
        valid_accuracy_history.append(valid_accuracy)

        valid_loss /= len(valid_loader)
        train_loss /= len(train_loader)
        loss_history.append(train_loss)
        valid_loss_history.append(valid_loss)

        print("epochs:",epoch,"Training loss:",train_loss,"Training Accuracy:",train_accuracy,"Validation Accuracy:",valid_accuracy,"Validation Loss:",valid_loss,"Learning rate:",scheduler.get_last_lr()[0])

        if valid_loss<min_loss:
            min_loss = valid_loss

        if valid_accuracy>max_accuracy:
            max_accuracy = valid_accuracy


print("Maximum Valid Accuracy:", max_accuracy, "Minimum Valid Loss:", min_loss)
# Out:
# Shape of training set: (6960, 22, 250)
# Shape of validation set: (1500, 22, 250)
# Shape of training labels: (6960,)
# Shape of validation labels: (1500,)
# Shape of testing set: (443, 22, 250)
# Shape of testing labels: (443,)
# Shape of training set after adding width info: (6960, 22, 250, 1)
# Shape of validation set after adding width info: (1500, 22, 250, 1)
# Shape of test set after adding width info: (443, 22, 250, 1)
# Shape of training set after dimension reshaping: (6960, 1, 22, 250)
# Shape of validation set after dimension reshaping: (1500, 1, 22, 250)
# Shape of test set after dimension reshaping: (443, 1, 22, 250)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 40, 22, 241]             440
#        BatchNorm2d-2          [-1, 40, 22, 241]              80
#               ReLU-3          [-1, 40, 22, 241]               0
#             Conv2d-4           [-1, 40, 1, 241]          35,240
#        BatchNorm2d-5           [-1, 40, 1, 241]              80
#               ReLU-6           [-1, 40, 1, 241]               0
#          AvgPool2d-7            [-1, 40, 1, 12]               0
#            Flatten-8                  [-1, 480]               0
#            Dropout-9                  [-1, 480]               0
#            Linear-10                    [-1, 4]           1,924
# ================================================================
# Total params: 37,764
# Trainable params: 37,764
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 5.09
# Params size (MB): 0.14
# Estimated Total Size (MB): 5.25
# ----------------------------------------------------------------
# epochs: 0 Training loss: 1.338006446578286 Training Accuracy: 0.3541666666666667 Validation Accuracy: 0.4609375 Validation Loss: 1.2840639253457387 Learning rate: 0.0008
# epochs: 1 Training loss: 1.2321086189963601 Training Accuracy: 0.5 Validation Accuracy: 0.4609375 Validation Loss: 1.195878932873408 Learning rate: 0.0008
# epochs: 2 Training loss: 1.1981237086382779 Training Accuracy: 0.3541666666666667 Validation Accuracy: 0.390625 Validation Loss: 1.061467210451762 Learning rate: 0.0008
# epochs: 3 Training loss: 1.2036135976964777 Training Accuracy: 0.3958333333333333 Validation Accuracy: 0.34375 Validation Loss: 1.1898501813411713 Learning rate: 0.0008
# epochs: 4 Training loss: 1.2256721084768123 Training Accuracy: 0.2708333333333333 Validation Accuracy: 0.4782608695652174 Validation Loss: 1.1941959857940674 Learning rate: 0.0008
# epochs: 5 Training loss: 1.1892747445539995 Training Accuracy: 0.4166666666666667 Validation Accuracy: 0.5 Validation Loss: 1.2061075568199158 Learning rate: 0.0008
# epochs: 6 Training loss: 1.1902226643128828 Training Accuracy: 0.6041666666666666 Validation Accuracy: 0.46875 Validation Loss: 0.9620772302150726 Learning rate: 0.0008
# epochs: 7 Training loss: 1.144159256328236 Training Accuracy: 0.4375 Validation Accuracy: 0.4140625 Validation Loss: 0.9573712150255839 Learning rate: 0.0008
# epochs: 8 Training loss: 1.1538992448286576 Training Accuracy: 0.5833333333333334 Validation Accuracy: 0.5234375 Validation Loss: 0.9924892286459605 Learning rate: 0.0008
# epochs: 9 Training loss: 1.174003046209162 Training Accuracy: 0.5833333333333334 Validation Accuracy: 0.4296875 Validation Loss: 0.9770992398262024 Learning rate: 0.0008
# epochs: 10 Training loss: 1.1747608748349276 Training Accuracy: 0.5208333333333334 Validation Accuracy: 0.5 Validation Loss: 0.9878119826316833 Learning rate: 0.0008
# epochs: 11 Training loss: 1.1407788753509522 Training Accuracy: 0.4583333333333333 Validation Accuracy: 0.578125 Validation Loss: 0.9625237882137299 Learning rate: 0.0008
# epochs: 12 Training loss: 1.1297957561232828 Training Accuracy: 0.5208333333333334 Validation Accuracy: 0.4609375 Validation Loss: 1.010786920785904 Learning rate: 0.0008
# epochs: 13 Training loss: 1.130252224748785 Training Accuracy: 0.5625 Validation Accuracy: 0.4453125 Validation Loss: 1.0270272394021351 Learning rate: 0.0008
# epochs: 14 Training loss: 1.1741332574324175 Training Accuracy: 0.4375 Validation Accuracy: 0.484375 Validation Loss: 0.9767412543296814 Learning rate: 0.0008
# epochs: 15 Training loss: 1.2523592190309005 Training Accuracy: 0.4375 Validation Accuracy: 0.4609375 Validation Loss: 1.0118502775828044 Learning rate: 0.0008
# epochs: 16 Training loss: 1.1280635064298457 Training Accuracy: 0.4375 Validation Accuracy: 0.5543478260869565 Validation Loss: 1.1290316780408223 Learning rate: 0.0008
# epochs: 17 Training loss: 1.1081604729999195 Training Accuracy: 0.5 Validation Accuracy: 0.4296875 Validation Loss: 0.9890538851420084 Learning rate: 0.0008
# epochs: 18 Training loss: 1.1593460700728677 Training Accuracy: 0.5625 Validation Accuracy: 0.515625 Validation Loss: 0.9729651510715485 Learning rate: 0.0008
# epochs: 19 Training loss: 1.1081012270667336 Training Accuracy: 0.5208333333333334 Validation Accuracy: 0.34375 Validation Loss: 0.9678217271963755 Learning rate: 0.0008
# epochs: 20 Training loss: 1.1235069621693003 Training Accuracy: 0.5625 Validation Accuracy: 0.3828125 Validation Loss: 0.9424885908762614 Learning rate: 0.0008
# epochs: 21 Training loss: 1.1096058347008444 Training Accuracy: 0.5 Validation Accuracy: 0.59375 Validation Loss: 0.9514825840791067 Learning rate: 0.0008
# epochs: 22 Training loss: 1.0879823836413296 Training Accuracy: 0.4166666666666667 Validation Accuracy: 0.5078125 Validation Loss: 1.01363143324852 Learning rate: 0.0008
# epochs: 23 Training loss: 1.109485678239302 Training Accuracy: 0.5416666666666666 Validation Accuracy: 0.5234375 Validation Loss: 0.9996834397315979 Learning rate: 0.0008
# epochs: 24 Training loss: 1.1314186974005265 Training Accuracy: 0.625 Validation Accuracy: 0.5078125 Validation Loss: 0.9816669821739197 Learning rate: 0.0008
# epochs: 25 Training loss: 1.1004496281797236 Training Accuracy: 0.4166666666666667 Validation Accuracy: 0.5234375 Validation Loss: 0.938594768444697 Learning rate: 0.0008
# epochs: 26 Training loss: 1.0734240477735346 Training Accuracy: 0.6041666666666666 Validation Accuracy: 0.3828125 Validation Loss: 0.9819423854351044 Learning rate: 0.0008
# epochs: 27 Training loss: 1.072359853441065 Training Accuracy: 0.5208333333333334 Validation Accuracy: 0.4609375 Validation Loss: 1.0035792887210846 Learning rate: 0.0008
# epochs: 28 Training loss: 1.0771831696683711 Training Accuracy: 0.4375 Validation Accuracy: 0.53125 Validation Loss: 0.9494592547416687 Learning rate: 0.0008
# epochs: 29 Training loss: 1.0463776371695779 Training Accuracy: 0.625 Validation Accuracy: 0.4375 Validation Loss: 0.9403429826100668 Learning rate: 0.0008
# epochs: 30 Training loss: 1.0927310087464073 Training Accuracy: 0.4375 Validation Accuracy: 0.5217391304347826 Validation Loss: 1.1181264321009319 Learning rate: 0.0008
# epochs: 31 Training loss: 1.0440032601356506 Training Accuracy: 0.5416666666666666 Validation Accuracy: 0.5078125 Validation Loss: 0.9229485392570496 Learning rate: 0.0008
# epochs: 32 Training loss: 1.0733873334797945 Training Accuracy: 0.6458333333333334 Validation Accuracy: 0.4765625 Validation Loss: 0.9223830898602804 Learning rate: 0.0008
# epochs: 33 Training loss: 1.036146418614821 Training Accuracy: 0.6875 Validation Accuracy: 0.4140625 Validation Loss: 0.9736444652080536 Learning rate: 0.0008
# epochs: 34 Training loss: 1.0712283275344154 Training Accuracy: 0.5833333333333334 Validation Accuracy: 0.484375 Validation Loss: 0.9299128452936808 Learning rate: 0.0008
# epochs: 35 Training loss: 1.0923906683921814 Training Accuracy: 0.5833333333333334 Validation Accuracy: 0.4765625 Validation Loss: 0.9301100373268127 Learning rate: 0.0008
# epochs: 36 Training loss: 1.0345639629797503 Training Accuracy: 0.5625 Validation Accuracy: 0.6413043478260869 Validation Loss: 1.08596870303154 Learning rate: 0.0008
# epochs: 37 Training loss: 0.9710428335449912 Training Accuracy: 0.5833333333333334 Validation Accuracy: 0.5625 Validation Loss: 0.9519611795743307 Learning rate: 0.0008
# epochs: 38 Training loss: 0.9847525770013983 Training Accuracy: 0.5208333333333334 Validation Accuracy: 0.5390625 Validation Loss: 0.9353442986806234 Learning rate: 0.0008
# epochs: 39 Training loss: 0.9570824493061413 Training Accuracy: 0.6041666666666666 Validation Accuracy: 0.5546875 Validation Loss: 0.9324427048365275 Learning rate: 0.0008
# epochs: 40 Training loss: 0.9360075723041188 Training Accuracy: 0.5208333333333334 Validation Accuracy: 0.5390625 Validation Loss: 0.9776962995529175 Learning rate: 0.0008
# epochs: 41 Training loss: 0.9595287691463124 Training Accuracy: 0.6041666666666666 Validation Accuracy: 0.546875 Validation Loss: 0.9465460479259491 Learning rate: 0.0008
# epochs: 42 Training loss: 1.0681252707134594 Training Accuracy: 0.6666666666666666 Validation Accuracy: 0.5625 Validation Loss: 0.9774928390979767 Learning rate: 0.0008
# epochs: 43 Training loss: 1.0384715036912398 Training Accuracy: 0.5208333333333334 Validation Accuracy: 0.4375 Validation Loss: 0.9384908179442087 Learning rate: 0.0008
# epochs: 44 Training loss: 1.0052470250563188 Training Accuracy: 0.75 Validation Accuracy: 0.53125 Validation Loss: 0.9795425534248352 Learning rate: 0.0008
# epochs: 45 Training loss: 1.0069606098261747 Training Accuracy: 0.6041666666666666 Validation Accuracy: 0.484375 Validation Loss: 0.9602889915307363 Learning rate: 0.0008
# epochs: 46 Training loss: 1.0733139753341674 Training Accuracy: 0.625 Validation Accuracy: 0.46875 Validation Loss: 0.986153801282247 Learning rate: 0.0008
# epochs: 47 Training loss: 1.0653931260108949 Training Accuracy: 0.5833333333333334 Validation Accuracy: 0.515625 Validation Loss: 0.9653692642847697 Learning rate: 0.0008
# epochs: 48 Training loss: 0.9918719801035795 Training Accuracy: 0.5 Validation Accuracy: 0.5978260869565217 Validation Loss: 1.1314831922451656 Learning rate: 0.0008
# epochs: 49 Training loss: 0.9590637467124246 Training Accuracy: 0.5208333333333334 Validation Accuracy: 0.4375 Validation Loss: 0.9551406900087992 Learning rate: 0.0008
# epochs: 50 Training loss: 1.0074204835024747 Training Accuracy: 0.6875 Validation Accuracy: 0.53125 Validation Loss: 0.9542970458666483 Learning rate: 0.0008
# epochs: 51 Training loss: 0.978701383417303 Training Accuracy: 0.6041666666666666 Validation Accuracy: 0.4765625 Validation Loss: 0.9531562527020773 Learning rate: 0.0008
# epochs: 52 Training loss: 0.9357399691234936 Training Accuracy: 0.6666666666666666 Validation Accuracy: 0.578125 Validation Loss: 0.9511149078607559 Learning rate: 0.0008
# epochs: 53 Training loss: 0.913462554324757 Training Accuracy: 0.625 Validation Accuracy: 0.5234375 Validation Loss: 0.9645477135976156 Learning rate: 0.0008
# epochs: 54 Training loss: 0.9058148644187234 Training Accuracy: 0.75 Validation Accuracy: 0.5625 Validation Loss: 0.9781961739063263 Learning rate: 0.0008
# epochs: 55 Training loss: 0.9339694272388112 Training Accuracy: 0.6041666666666666 Validation Accuracy: 0.5625 Validation Loss: 0.9784194429715475 Learning rate: 0.0008
# epochs: 56 Training loss: 0.9027556256814436 Training Accuracy: 0.7291666666666666 Validation Accuracy: 0.59375 Validation Loss: 0.9897111852963766 Learning rate: 0.0008
# epochs: 57 Training loss: 0.8657573396509344 Training Accuracy: 0.7291666666666666 Validation Accuracy: 0.5234375 Validation Loss: 0.968675563732783 Learning rate: 0.0008
# epochs: 58 Training loss: 0.9247815587303855 Training Accuracy: 0.6041666666666666 Validation Accuracy: 0.46875 Validation Loss: 0.9746218125025431 Learning rate: 0.0008
# epochs: 59 Training loss: 0.936058992689306 Training Accuracy: 0.5416666666666666 Validation Accuracy: 0.609375 Validation Loss: 0.9718284904956818 Learning rate: 0.0008
# epochs: 60 Training loss: 0.9245943492109125 Training Accuracy: 0.7083333333333334 Validation Accuracy: 0.4453125 Validation Loss: 0.9259955088297526 Learning rate: 0.0008
# epochs: 61 Training loss: 0.914715424450961 Training Accuracy: 0.6041666666666666 Validation Accuracy: 0.5625 Validation Loss: 0.9907688796520233 Learning rate: 0.0008
# epochs: 62 Training loss: 0.9096423214132136 Training Accuracy: 0.5833333333333334 Validation Accuracy: 0.4765625 Validation Loss: 1.0032845934232075 Learning rate: 0.0008
# epochs: 63 Training loss: 0.9459314931522717 Training Accuracy: 0.5416666666666666 Validation Accuracy: 0.5234375 Validation Loss: 0.9299474457899729 Learning rate: 0.0008
# epochs: 64 Training loss: 0.9548632990230214 Training Accuracy: 0.7083333333333334 Validation Accuracy: 0.5625 Validation Loss: 0.9347493648529053 Learning rate: 0.0008
# epochs: 65 Training loss: 0.9478199850429189 Training Accuracy: 0.6458333333333334 Validation Accuracy: 0.578125 Validation Loss: 0.9328921884298325 Learning rate: 0.0008
# epochs: 66 Training loss: 0.9528901295228438 Training Accuracy: 0.6458333333333334 Validation Accuracy: 0.5234375 Validation Loss: 0.9830579857031504 Learning rate: 0.0008
# epochs: 67 Training loss: 0.9213447960940274 Training Accuracy: 0.6458333333333334 Validation Accuracy: 0.4296875 Validation Loss: 0.9229948123296102 Learning rate: 0.0008
# epochs: 68 Training loss: 0.9258728428320451 Training Accuracy: 0.6666666666666666 Validation Accuracy: 0.546875 Validation Loss: 0.9478912850220998 Learning rate: 0.0008
# epochs: 69 Training loss: 0.9137361884117127 Training Accuracy: 0.6666666666666666 Validation Accuracy: 0.5546875 Validation Loss: 0.9570837418238322 Learning rate: 0.0008
# epochs: 70 Training loss: 0.8962977907874368 Training Accuracy: 0.6458333333333334 Validation Accuracy: 0.5703125 Validation Loss: 0.9265297849973043 Learning rate: 0.0008
# epochs: 71 Training loss: 0.8743496082045815 Training Accuracy: 0.5833333333333334 Validation Accuracy: 0.6195652173913043 Validation Loss: 1.1234530160824459 Learning rate: 0.0008
# epochs: 72 Training loss: 0.8908838824792342 Training Accuracy: 0.6041666666666666 Validation Accuracy: 0.5078125 Validation Loss: 0.962632934252421 Learning rate: 0.0008
# epochs: 73 Training loss: 0.8662454800172286 Training Accuracy: 0.7083333333333334 Validation Accuracy: 0.5703125 Validation Loss: 0.9564173916975657 Learning rate: 0.0008
# epochs: 74 Training loss: 0.8630777402357621 Training Accuracy: 0.6666666666666666 Validation Accuracy: 0.4375 Validation Loss: 0.9462287227312723 Learning rate: 0.0008
# epochs: 75 Training loss: 0.871222891590812 Training Accuracy: 0.625 Validation Accuracy: 0.53125 Validation Loss: 0.9282779892285665 Learning rate: 0.0008
# epochs: 76 Training loss: 0.863619024103338 Training Accuracy: 0.6458333333333334 Validation Accuracy: 0.515625 Validation Loss: 0.9224002957344055 Learning rate: 0.0008
# epochs: 77 Training loss: 0.8345245480537414 Training Accuracy: 0.6458333333333334 Validation Accuracy: 0.578125 Validation Loss: 0.9611527224381765 Learning rate: 0.0008
# epochs: 78 Training loss: 0.805038426139138 Training Accuracy: 0.7916666666666666 Validation Accuracy: 0.5546875 Validation Loss: 0.9710778097311655 Learning rate: 0.0008
# epochs: 79 Training loss: 0.8033394152467901 Training Accuracy: 0.75 Validation Accuracy: 0.53125 Validation Loss: 0.9240502218405405 Learning rate: 0.0008
# epochs: 80 Training loss: 0.8392897551709956 Training Accuracy: 0.6041666666666666 Validation Accuracy: 0.53125 Validation Loss: 0.9272602001825968 Learning rate: 0.0008
# epochs: 81 Training loss: 0.8434905604882674 Training Accuracy: 0.6458333333333334 Validation Accuracy: 0.59375 Validation Loss: 0.9943690896034241 Learning rate: 0.0008
# epochs: 82 Training loss: 0.8160351536490701 Training Accuracy: 0.6875 Validation Accuracy: 0.5546875 Validation Loss: 0.9371642569700877 Learning rate: 0.0008
# epochs: 83 Training loss: 0.8247067169709639 Training Accuracy: 0.7291666666666666 Validation Accuracy: 0.5703125 Validation Loss: 0.9719964563846588 Learning rate: 0.0008
# epochs: 84 Training loss: 0.8232605619864031 Training Accuracy: 0.7916666666666666 Validation Accuracy: 0.609375 Validation Loss: 0.9382638037204742 Learning rate: 0.0008
# epochs: 85 Training loss: 0.8370432886210355 Training Accuracy: 0.5625 Validation Accuracy: 0.5859375 Validation Loss: 1.0108010272185008 Learning rate: 0.0008
# epochs: 86 Training loss: 0.8228351961482655 Training Accuracy: 0.75 Validation Accuracy: 0.5625 Validation Loss: 0.9542352457841238 Learning rate: 0.0008
# epochs: 87 Training loss: 0.8371692158959129 Training Accuracy: 0.5833333333333334 Validation Accuracy: 0.5625 Validation Loss: 1.0025888482729595 Learning rate: 0.0008
# epochs: 88 Training loss: 0.7925864685665477 Training Accuracy: 0.625 Validation Accuracy: 0.578125 Validation Loss: 0.949964185555776 Learning rate: 0.0008
# epochs: 89 Training loss: 0.7853496042164889 Training Accuracy: 0.6666666666666666 Validation Accuracy: 0.5625 Validation Loss: 0.9470772842566172 Learning rate: 0.0008
# epochs: 90 Training loss: 0.8309913786974821 Training Accuracy: 0.6041666666666666 Validation Accuracy: 0.5078125 Validation Loss: 0.9844329655170441 Learning rate: 0.0008
# epochs: 91 Training loss: 0.8040566671978343 Training Accuracy: 0.6875 Validation Accuracy: 0.5234375 Validation Loss: 0.969355841477712 Learning rate: 0.0008
# epochs: 92 Training loss: 0.903932739387859 Training Accuracy: 0.7291666666666666 Validation Accuracy: 0.5078125 Validation Loss: 0.9709710975488027 Learning rate: 0.0008
# epochs: 93 Training loss: 0.9475836472077803 Training Accuracy: 0.75 Validation Accuracy: 0.5703125 Validation Loss: 1.0055117706457775 Learning rate: 0.0008
# epochs: 94 Training loss: 0.8423662781715393 Training Accuracy: 0.6041666666666666 Validation Accuracy: 0.53125 Validation Loss: 0.9748886227607727 Learning rate: 0.0008
# epochs: 95 Training loss: 0.8007003849202936 Training Accuracy: 0.7083333333333334 Validation Accuracy: 0.53125 Validation Loss: 0.9472267727057139 Learning rate: 0.0008
# epochs: 96 Training loss: 0.8332636150446805 Training Accuracy: 0.6041666666666666 Validation Accuracy: 0.53125 Validation Loss: 0.9296025534470876 Learning rate: 0.0008
# epochs: 97 Training loss: 0.8576415051113475 Training Accuracy: 0.5833333333333334 Validation Accuracy: 0.59375 Validation Loss: 0.9733313024044037 Learning rate: 0.0008
# epochs: 98 Training loss: 0.8304873444817283 Training Accuracy: 0.6458333333333334 Validation Accuracy: 0.5703125 Validation Loss: 0.9941381911436716 Learning rate: 0.0008
# epochs: 99 Training loss: 0.7978205594149503 Training Accuracy: 0.8125 Validation Accuracy: 0.5 Validation Loss: 0.9497477412223816 Learning rate: 0.0008
# Maximum Valid Accuracy: 0.6413043478260869 Minimum Valid Loss: 0.9223830898602804

# %% [markdown]
# ## Plot Graphs of Accuracy and Loss

# %%
plt.plot(range(epochs), train_accuracy_history, 'b-', label='Train')
plt.plot(range(epochs), valid_accuracy_history, 'r-', label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.legend()

# %%
plt.plot(range(epochs), loss_history, 'b-', label='Train')
plt.plot(range(epochs), valid_loss_history, 'r-', label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# %%
## Testing the ShallowConvNet model on all subjects

test_acc, test_loss = testing(test_loader, model, device)
print('Test accuracy of the ShallowConvNet model on all subjects:', test_acc)
# Out:
# Test accuracy of the ShallowConvNet model on all subjects: 0.6101694915254238

# %%
def test_single(x_test, y_test, model, person_test, batch_size, sub_idx=None, time_period=1000):
    X_test_cur = x_test[:, :, :time_period]
    y_test_cur = y_test

    if sub_idx is not None:
        X_test_cur = X_test_cur[np.where(person_test == sub_idx)[0]]
        y_test_cur = y_test[np.where(person_test == sub_idx)[0]]

    test_single_dataset = torch.utils.data.TensorDataset(torch.tensor(X_test_cur).float(), torch.tensor(y_test_cur).long())
    test_single_loader = torch.utils.data.DataLoader(test_single_dataset, batch_size=batch_size)

    model.eval()
    valid_single_loss = 0
    with torch.no_grad():
        model.cuda(0)
        for inputs, targets in test_single_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            n = targets.shape[0]
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            valid_single_loss += loss.item()
            valid_loss_history.append(valid_single_loss)
            correct_test = (torch.max(outputs,1)[1]==targets).sum().item()
        test_single_accuracy = correct_test/n
        valid_single_loss /= len(valid_loader)
            # print("testing accuracy:",correct/n)
    return test_single_accuracy, valid_loss

# %%
## Testing the ShallowConvNet model on Subject 0

test_single_acc, test_single_loss = test_single(x_test, y_test, model, person_test, batch_size=128, sub_idx=0)
print('Test accuracy of the ShallowConvNet model on Subject 0:', test_single_acc)
# Out:
# Test accuracy of the ShallowConvNet model on Subject 0: 0.48

# %%
def data_prep(X,y):

    total_X = None
    total_y = None

    # Noise
    X_average = X + np.random.normal(0.0, 0.5, X.shape)

    total_X =  X_average
    total_y =  y

    print('Shape of X after noise:',total_X.shape)

    return total_X,total_y

# %%
def load_data_time_bin(time, debug=True, onehot=False, time_bin=True):

## Loading the dataset
    X_test = np.load("X_test.npy")
    y_test = np.load("y_test.npy")
    person_train_valid = np.load("person_train_valid.npy")
    X_train_valid = np.load("X_train_valid.npy")
    y_train_valid = np.load("y_train_valid.npy")
    person_test = np.load("person_test.npy")

    ## Adjusting the labels so that

    # Cue onset left - 0
    # Cue onset right - 1
    # Cue onset foot - 2
    # Cue onset tongue - 3

    y_train_valid -= 769
    y_test -= 769

    print(X_train_valid.shape)
    print(y_train_valid.shape)
    print(X_test.shape)
    print(y_test.shape)
    print (person_train_valid.shape)
    print (person_test.shape)

    ## Preprocessing dataset
    if time_bin:
      X_train_valid,y_train_valid = data_prep(X_train_valid,y_train_valid)

    if debug:
        print('Shape of training/validation set:',X_train_valid.shape)
        print('Shape of training/validation labels:',y_train_valid.shape)
        print('Shape of testing set:',X_test.shape)
        print('Shape of testing labels:',y_test.shape)


    if onehot:
        # Converting the labels to categorical variables for multiclass classification
        y_train_valid = to_categorical(y_train_valid, 4)
        y_test = to_categorical(y_test, 4)
        if debug:
            print('Shape of training/valid labels after categorical conversion:',y_train_valid.shape)
            print('Shape of test labels after categorical conversion:',y_test.shape)

    # Adding width of the segment to be 1
    X_train_valid = X_train_valid.reshape(X_train_valid.shape[0], X_train_valid.shape[1], X_train_valid.shape[2], 1)
    x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)
    if debug:
        print('Shape of training set after adding width info:',X_train_valid.shape)
        print('Shape of test set after adding width info:',x_test.shape)


    # Reshaping the training and validation dataset
    x_test = np.swapaxes(x_test, 1,3)
    x_test = np.swapaxes(x_test, 2,3)
    X_train_valid = np.swapaxes(X_train_valid, 1,3)
    X_train_valid = np.swapaxes(X_train_valid, 2,3)

    if debug:
        print('Shape of training/validation set after dimension reshaping:',X_train_valid.shape)
        print('Shape of test set after dimension reshaping:',x_test.shape)

    return X_train_valid, y_train_valid, x_test, y_test

# %%
time = 1000
## Preprocessing the dataset

x_train_valid, y_train_valid, x_test, y_test = load_data_time_bin(time=time, onehot=False, time_bin=True)
# Out:
# (2115, 22, 1000)
# (2115,)
# (443, 22, 1000)
# (443,)
# (2115, 1)
# (443, 1)
# Shape of X after noise: (2115, 22, 1000)
# Shape of training/validation set: (2115, 22, 1000)
# Shape of training/validation labels: (2115,)
# Shape of testing set: (443, 22, 1000)
# Shape of testing labels: (443,)
# Shape of training set after adding width info: (2115, 22, 1000, 1)
# Shape of test set after adding width info: (443, 22, 1000, 1)
# Shape of training/validation set after dimension reshaping: (2115, 1, 22, 1000)
# Shape of test set after dimension reshaping: (443, 1, 22, 1000)

# %% [markdown]
# ## Training of Model for different time bins

# %%
def get_model(time, n_output):
    if time == 250:
      units = 480
    elif time == 500:
      units = 1120
    elif time == 750:
      units = 1800
    elif time == 1000:
      units = 2480
    class ShallowConvNet(nn.Module):
        def __init__(self, time, n_output):
            super(ShallowConvNet, self).__init__()
            self.conv1 = nn.Conv2d(1, 40, kernel_size=(1, 10))
            self.conv2 = nn.Conv2d(40, 40, kernel_size=(22, 1))
            self.batchnorm = nn.BatchNorm2d(40)
            self.activation = nn.ReLU()
            self.avgpool = nn.AvgPool2d(kernel_size=(1, 75), stride=(1, 15))
            self.dropout = nn.Dropout(0.4)
            self.flatten = nn.Flatten()
            self.fc = nn.Linear(units, n_output)

        def forward(self, x):
            x = self.activation(self.batchnorm(self.conv1(x)))
            x = self.activation(self.batchnorm(self.conv2(x)))
            x = self.avgpool(x)
            x = torch.log(torch.clamp(x, min=1e-06))
            x = self.flatten(x)
            x = self.dropout(x)
            x = self.fc(x)
            return x

    return ShallowConvNet(time, n_output)

# %%
epochs = 50
lr = 1e-3

new_model = get_model(time, n_output = 4)
new_criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(new_model.parameters(), lr=lr)
#optimizer = optim.RMSprop(model.parameters(),lr = lr, momentum = 0.6)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[1,3,5], gamma=0.1)
early_stopper = EarlyStopper(patience=3, min_delta=10)

# %%
def train(time_period):
  min_loss=1
  max_accuracy = 0
  max_train_valid_accuracy = 0

  X_train_valid_cur = x_train_valid[:, :, :, :time_period]
  y_train_valid_cur = y_train_valid
  X_test_cur = x_test[:, :, :, :time_period]
  y_test_cur = y_test

  # Convert numpy arrays to PyTorch tensors
  x_train_valid_tensor = torch.tensor(X_train_valid_cur).float()
  y_train_valid_tensor = torch.tensor(y_train_valid_cur).long()
  x_test_tensor = torch.tensor(X_test_cur).float()
  y_test_tensor = torch.tensor(y_test_cur).long()

  # Create PyTorch datasets
  train_valid_dataset = TensorDataset(x_train_valid_tensor, y_train_valid_tensor)
  test_dataset = TensorDataset(x_test_tensor, y_test_tensor)

  # Define batch size and create data loaders
  batch_size = 128
  train_valid_loader = DataLoader(train_valid_dataset, batch_size=batch_size, shuffle=True)
  test_loader = DataLoader(test_dataset, batch_size=batch_size)

  new_model = get_model(time_period, n_output = 4)
  summary(new_model.cuda(),(1,22,time_period))

  loss_history = []
  train_valid_accuracy_history = []
  test_accuracy_history = []
  test_loss_history = []

  # Train the model
  for epoch in range(epochs):
      train_valid_loss = 0
      for inputs, targets in train_valid_loader:
          inputs, targets = inputs.to(device), targets.to(device)
          outputs = new_model(inputs)
          loss = new_criterion(outputs, targets)
          train_valid_loss += loss.item()
          optimizer.zero_grad()
          loss.backward()
          optimizer.step()

      if epoch%1==0:
          n = targets.shape[0]
          correct = (torch.max(outputs,1)[1]==targets).sum().item()
          train_valid_accuracy = correct / n
          train_valid_accuracy_history.append(train_accuracy)

          model.eval()
          test_loss = 0
          with torch.no_grad():
              model.cuda(0)
              for inputs, targets in test_loader:
                  inputs, targets = inputs.to(device), targets.to(device)
                  n = targets.shape[0]
                  outputs = new_model(inputs)
                  vloss = criterion(outputs, targets)
                  test_loss += vloss.item()
                  if early_stopper.early_stop(test_loss):
                    break

          correct_test = (torch.max(outputs,1)[1]==targets).sum().item()
          test_accuracy = correct_test/n
          test_accuracy_history.append(test_accuracy)

          test_loss /= len(test_loader)
          train_valid_loss /= len(train_valid_loader)
          loss_history.append(train_valid_loss)
          test_loss_history.append(test_loss)

          print("epochs:",epoch,"Training/Validation loss:",train_valid_loss,"Training/Validation Accuracy:",train_valid_accuracy,"Test Accuracy:",test_accuracy,"Test Loss:",test_loss,"Learning rate:",scheduler.get_last_lr()[0])

          if test_loss<min_loss:
              min_loss = test_loss

          if test_accuracy>max_accuracy:
              max_accuracy = test_accuracy

          if train_valid_accuracy>max_train_valid_accuracy:
              max_train_valid_accuracy = train_valid_accuracy

  print("Time:", str(time), "Maximum Test Accuracy:", max_accuracy, "Minimum Valid Loss:", min_loss)

  return max_train_valid_accuracy, max_accuracy

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

train_scores = []
test_scores = []

for time in range(250, 1001, 250):
    print(str(time))
    train_valid_accuracy, test_accuracy = train(time_period=time)
    train_scores.append(train_valid_accuracy)
    test_scores.append(test_accuracy)


print("Train accuracies: ")
print(train_scores)
print("Test accuracies: ")
print(test_scores)

max_idx = np.argmax(test_scores)
print("The best accuracy is %.3f." % max(test_scores))
print("The corresponding time period is %d." % (250 + 250 * max_idx))

# plot
plt.plot(range(250, 1001, 250), train_scores, label='Train accuracies')
plt.plot(range(250, 1001, 250), test_scores, label='Test accuracies')
plt.legend()
plt.title("Classification Accuracies over Time Period (CNN)")
plt.show()
# Out:
# 250
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 40, 22, 241]             440
#        BatchNorm2d-2          [-1, 40, 22, 241]              80
#               ReLU-3          [-1, 40, 22, 241]               0
#             Conv2d-4           [-1, 40, 1, 241]          35,240
#        BatchNorm2d-5           [-1, 40, 1, 241]              80
#               ReLU-6           [-1, 40, 1, 241]               0
#          AvgPool2d-7            [-1, 40, 1, 12]               0
#            Flatten-8                  [-1, 480]               0
#            Dropout-9                  [-1, 480]               0
#            Linear-10                    [-1, 4]           1,924
# ================================================================
# Total params: 37,764
# Trainable params: 37,764
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 5.09
# Params size (MB): 0.14
# Estimated Total Size (MB): 5.25
# ----------------------------------------------------------------
# epochs: 0 Training/Validation loss: 1.5889516297508688 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.2542372881355932 Test Loss: 1.581650584936142 Learning rate: 0.001
# epochs: 1 Training/Validation loss: 1.5819952908684225 Training/Validation Accuracy: 0.3880597014925373 Test Accuracy: 0.2033898305084746 Test Loss: 1.6040559709072113 Learning rate: 0.001
# epochs: 2 Training/Validation loss: 1.6416332791833317 Training/Validation Accuracy: 0.19402985074626866 Test Accuracy: 0.2542372881355932 Test Loss: 1.5581603944301605 Learning rate: 0.001
# epochs: 3 Training/Validation loss: 1.5919012181899126 Training/Validation Accuracy: 0.1791044776119403 Test Accuracy: 0.2711864406779661 Test Loss: 1.5681460201740265 Learning rate: 0.001
# epochs: 4 Training/Validation loss: 1.5890447532429415 Training/Validation Accuracy: 0.3283582089552239 Test Accuracy: 0.23728813559322035 Test Loss: 1.5424412488937378 Learning rate: 0.001
# epochs: 5 Training/Validation loss: 1.5647582306581385 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.288135593220339 Test Loss: 1.5228530168533325 Learning rate: 0.001
# epochs: 6 Training/Validation loss: 1.6198517855475931 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.3389830508474576 Test Loss: 1.576090931892395 Learning rate: 0.001
# epochs: 7 Training/Validation loss: 1.6199367116479313 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.2542372881355932 Test Loss: 1.5426792800426483 Learning rate: 0.001
# epochs: 8 Training/Validation loss: 1.5942039980607874 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.288135593220339 Test Loss: 1.5005882382392883 Learning rate: 0.001
# epochs: 9 Training/Validation loss: 1.584785166908713 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.2542372881355932 Test Loss: 1.5564096570014954 Learning rate: 0.001
# epochs: 10 Training/Validation loss: 1.6294763368718765 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.1864406779661017 Test Loss: 1.5229194164276123 Learning rate: 0.001
# epochs: 11 Training/Validation loss: 1.6114324191037346 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.23728813559322035 Test Loss: 1.6400269269943237 Learning rate: 0.001
# epochs: 12 Training/Validation loss: 1.6058013859917135 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.288135593220339 Test Loss: 1.5837876498699188 Learning rate: 0.001
# epochs: 13 Training/Validation loss: 1.5983209399616016 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.2542372881355932 Test Loss: 1.5401563942432404 Learning rate: 0.001
# epochs: 14 Training/Validation loss: 1.6255075651056625 Training/Validation Accuracy: 0.208955223880597 Test Accuracy: 0.23728813559322035 Test Loss: 1.5410404205322266 Learning rate: 0.001
# epochs: 15 Training/Validation loss: 1.5923885247286629 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.2711864406779661 Test Loss: 1.5573557317256927 Learning rate: 0.001
# epochs: 16 Training/Validation loss: 1.6023825056412642 Training/Validation Accuracy: 0.22388059701492538 Test Accuracy: 0.3728813559322034 Test Loss: 1.5626144707202911 Learning rate: 0.001
# epochs: 17 Training/Validation loss: 1.6173558515660904 Training/Validation Accuracy: 0.19402985074626866 Test Accuracy: 0.1864406779661017 Test Loss: 1.5522057116031647 Learning rate: 0.001
# epochs: 18 Training/Validation loss: 1.5868787134394926 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.288135593220339 Test Loss: 1.537401795387268 Learning rate: 0.001
# epochs: 19 Training/Validation loss: 1.6091561948551851 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.2711864406779661 Test Loss: 1.5646970868110657 Learning rate: 0.001
# epochs: 20 Training/Validation loss: 1.6113986408009249 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.2033898305084746 Test Loss: 1.6121710240840912 Learning rate: 0.001
# epochs: 21 Training/Validation loss: 1.5919978688744938 Training/Validation Accuracy: 0.22388059701492538 Test Accuracy: 0.2033898305084746 Test Loss: 1.5781988501548767 Learning rate: 0.001
# epochs: 22 Training/Validation loss: 1.6007197674582987 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.3220338983050847 Test Loss: 1.551584780216217 Learning rate: 0.001
# epochs: 23 Training/Validation loss: 1.5854846098843742 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.3050847457627119 Test Loss: 1.5497624576091766 Learning rate: 0.001
# epochs: 24 Training/Validation loss: 1.600162478054271 Training/Validation Accuracy: 0.22388059701492538 Test Accuracy: 0.3220338983050847 Test Loss: 1.5647644698619843 Learning rate: 0.001
# epochs: 25 Training/Validation loss: 1.6278488145155066 Training/Validation Accuracy: 0.19402985074626866 Test Accuracy: 0.22033898305084745 Test Loss: 1.5845836400985718 Learning rate: 0.001
# epochs: 26 Training/Validation loss: 1.6314060477649464 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.2033898305084746 Test Loss: 1.578378677368164 Learning rate: 0.001
# epochs: 27 Training/Validation loss: 1.6230647914549883 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.2033898305084746 Test Loss: 1.5789174735546112 Learning rate: 0.001
# epochs: 28 Training/Validation loss: 1.592458402409273 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.23728813559322035 Test Loss: 1.578210562467575 Learning rate: 0.001
# epochs: 29 Training/Validation loss: 1.6000853005577536 Training/Validation Accuracy: 0.22388059701492538 Test Accuracy: 0.2033898305084746 Test Loss: 1.5963588953018188 Learning rate: 0.001
# epochs: 30 Training/Validation loss: 1.5798077372943653 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.1864406779661017 Test Loss: 1.5995985269546509 Learning rate: 0.001
# epochs: 31 Training/Validation loss: 1.6049491377437817 Training/Validation Accuracy: 0.208955223880597 Test Accuracy: 0.23728813559322035 Test Loss: 1.5390325784683228 Learning rate: 0.001
# epochs: 32 Training/Validation loss: 1.588485226911657 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.23728813559322035 Test Loss: 1.5279102623462677 Learning rate: 0.001
# epochs: 33 Training/Validation loss: 1.5932971309213078 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.3220338983050847 Test Loss: 1.5123164355754852 Learning rate: 0.001
# epochs: 34 Training/Validation loss: 1.5977535177679623 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.2711864406779661 Test Loss: 1.5841051936149597 Learning rate: 0.001
# epochs: 35 Training/Validation loss: 1.594079718870275 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.2542372881355932 Test Loss: 1.5950354933738708 Learning rate: 0.001
# epochs: 36 Training/Validation loss: 1.619435562806971 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.1694915254237288 Test Loss: 1.5676749646663666 Learning rate: 0.001
# epochs: 37 Training/Validation loss: 1.5805476623422958 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.2711864406779661 Test Loss: 1.5439069271087646 Learning rate: 0.001
# epochs: 38 Training/Validation loss: 1.593329254318686 Training/Validation Accuracy: 0.19402985074626866 Test Accuracy: 0.2033898305084746 Test Loss: 1.578027606010437 Learning rate: 0.001
# epochs: 39 Training/Validation loss: 1.5693392192616182 Training/Validation Accuracy: 0.373134328358209 Test Accuracy: 0.3220338983050847 Test Loss: 1.529463768005371 Learning rate: 0.001
# epochs: 40 Training/Validation loss: 1.6170611101038315 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.288135593220339 Test Loss: 1.555661380290985 Learning rate: 0.001
# epochs: 41 Training/Validation loss: 1.6167597770690918 Training/Validation Accuracy: 0.1791044776119403 Test Accuracy: 0.22033898305084745 Test Loss: 1.572970986366272 Learning rate: 0.001
# epochs: 42 Training/Validation loss: 1.6153895083595724 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.1864406779661017 Test Loss: 1.5990038514137268 Learning rate: 0.001
# epochs: 43 Training/Validation loss: 1.5995383052264942 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.1694915254237288 Test Loss: 1.595483511686325 Learning rate: 0.001
# epochs: 44 Training/Validation loss: 1.571225362665513 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.2711864406779661 Test Loss: 1.5665620565414429 Learning rate: 0.001
# epochs: 45 Training/Validation loss: 1.607955862494076 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.23728813559322035 Test Loss: 1.6146019399166107 Learning rate: 0.001
# epochs: 46 Training/Validation loss: 1.6171222083708818 Training/Validation Accuracy: 0.19402985074626866 Test Accuracy: 0.23728813559322035 Test Loss: 1.5941567718982697 Learning rate: 0.001
# epochs: 47 Training/Validation loss: 1.6180685407975142 Training/Validation Accuracy: 0.373134328358209 Test Accuracy: 0.1864406779661017 Test Loss: 1.5532521307468414 Learning rate: 0.001
# epochs: 48 Training/Validation loss: 1.6100654111189001 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.2542372881355932 Test Loss: 1.5074365735054016 Learning rate: 0.001
# epochs: 49 Training/Validation loss: 1.6101557366988237 Training/Validation Accuracy: 0.3582089552238806 Test Accuracy: 0.1694915254237288 Test Loss: 1.6225055158138275 Learning rate: 0.001
# Time: 250 Maximum Test Accuracy: 0.3728813559322034 Minimum Valid Loss: 1
# 500
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 40, 22, 491]             440
#        BatchNorm2d-2          [-1, 40, 22, 491]              80
#               ReLU-3          [-1, 40, 22, 491]               0
#             Conv2d-4           [-1, 40, 1, 491]          35,240
#        BatchNorm2d-5           [-1, 40, 1, 491]              80
#               ReLU-6           [-1, 40, 1, 491]               0
#          AvgPool2d-7            [-1, 40, 1, 28]               0
#            Flatten-8                 [-1, 1120]               0
#            Dropout-9                 [-1, 1120]               0
#            Linear-10                    [-1, 4]           4,484
# ================================================================
# Total params: 40,324
# Trainable params: 40,324
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.04
# Forward/backward pass size (MB): 10.36
# Params size (MB): 0.15
# Estimated Total Size (MB): 10.56
# ----------------------------------------------------------------
# epochs: 0 Training/Validation loss: 1.7251653390772201 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.2711864406779661 Test Loss: 1.6696088314056396 Learning rate: 0.001
# epochs: 1 Training/Validation loss: 1.687559864100288 Training/Validation Accuracy: 0.19402985074626866 Test Accuracy: 0.3050847457627119 Test Loss: 1.7461360692977905 Learning rate: 0.001
# epochs: 2 Training/Validation loss: 1.6878023428075455 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.2033898305084746 Test Loss: 1.7815974056720734 Learning rate: 0.001
# epochs: 3 Training/Validation loss: 1.670048896004172 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.2542372881355932 Test Loss: 1.7327607870101929 Learning rate: 0.001
# epochs: 4 Training/Validation loss: 1.7175682081895716 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.1864406779661017 Test Loss: 1.785163164138794 Learning rate: 0.001
# epochs: 5 Training/Validation loss: 1.6891179715885836 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.2711864406779661 Test Loss: 1.7310950458049774 Learning rate: 0.001
# epochs: 6 Training/Validation loss: 1.6744743094724768 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.22033898305084745 Test Loss: 1.7537669837474823 Learning rate: 0.001
# epochs: 7 Training/Validation loss: 1.6872292476541855 Training/Validation Accuracy: 0.208955223880597 Test Accuracy: 0.15254237288135594 Test Loss: 1.7398075461387634 Learning rate: 0.001
# epochs: 8 Training/Validation loss: 1.6823662519454956 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.2542372881355932 Test Loss: 1.7365607619285583 Learning rate: 0.001
# epochs: 9 Training/Validation loss: 1.6680761715945076 Training/Validation Accuracy: 0.22388059701492538 Test Accuracy: 0.288135593220339 Test Loss: 1.7550920248031616 Learning rate: 0.001
# epochs: 10 Training/Validation loss: 1.6904050462386186 Training/Validation Accuracy: 0.22388059701492538 Test Accuracy: 0.1016949152542373 Test Loss: 1.7502756118774414 Learning rate: 0.001
# epochs: 11 Training/Validation loss: 1.707619491745444 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.22033898305084745 Test Loss: 1.7312687933444977 Learning rate: 0.001
# epochs: 12 Training/Validation loss: 1.6819686398786657 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.2033898305084746 Test Loss: 1.7569082081317902 Learning rate: 0.001
# epochs: 13 Training/Validation loss: 1.7030489023993998 Training/Validation Accuracy: 0.208955223880597 Test Accuracy: 0.23728813559322035 Test Loss: 1.7452542781829834 Learning rate: 0.001
# epochs: 14 Training/Validation loss: 1.6762964445001938 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.288135593220339 Test Loss: 1.743732213973999 Learning rate: 0.001
# epochs: 15 Training/Validation loss: 1.668562229941873 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.22033898305084745 Test Loss: 1.7359456717967987 Learning rate: 0.001
# epochs: 16 Training/Validation loss: 1.6934844185324276 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.22033898305084745 Test Loss: 1.7543575465679169 Learning rate: 0.001
# epochs: 17 Training/Validation loss: 1.6508937513127047 Training/Validation Accuracy: 0.3283582089552239 Test Accuracy: 0.1694915254237288 Test Loss: 1.7726753056049347 Learning rate: 0.001
# epochs: 18 Training/Validation loss: 1.7087202563005335 Training/Validation Accuracy: 0.208955223880597 Test Accuracy: 0.2542372881355932 Test Loss: 1.7387314140796661 Learning rate: 0.001
# epochs: 19 Training/Validation loss: 1.6928016858942367 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.2711864406779661 Test Loss: 1.7291393280029297 Learning rate: 0.001
# epochs: 20 Training/Validation loss: 1.6989220450906193 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.288135593220339 Test Loss: 1.7629656493663788 Learning rate: 0.001
# epochs: 21 Training/Validation loss: 1.6823683416142183 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.23728813559322035 Test Loss: 1.7178913950920105 Learning rate: 0.001
# epochs: 22 Training/Validation loss: 1.683557342080509 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.22033898305084745 Test Loss: 1.7607017159461975 Learning rate: 0.001
# epochs: 23 Training/Validation loss: 1.6566221643896664 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.15254237288135594 Test Loss: 1.721221148967743 Learning rate: 0.001
# epochs: 24 Training/Validation loss: 1.6763062757604263 Training/Validation Accuracy: 0.16417910447761194 Test Accuracy: 0.2542372881355932 Test Loss: 1.7530708014965057 Learning rate: 0.001
# epochs: 25 Training/Validation loss: 1.6950737658668966 Training/Validation Accuracy: 0.3582089552238806 Test Accuracy: 0.2542372881355932 Test Loss: 1.7393784523010254 Learning rate: 0.001
# epochs: 26 Training/Validation loss: 1.674088064362021 Training/Validation Accuracy: 0.1791044776119403 Test Accuracy: 0.22033898305084745 Test Loss: 1.7289936542510986 Learning rate: 0.001
# epochs: 27 Training/Validation loss: 1.6609185513328104 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.2542372881355932 Test Loss: 1.7521747648715973 Learning rate: 0.001
# epochs: 28 Training/Validation loss: 1.684025897699244 Training/Validation Accuracy: 0.19402985074626866 Test Accuracy: 0.23728813559322035 Test Loss: 1.6817308366298676 Learning rate: 0.001
# epochs: 29 Training/Validation loss: 1.6825152916066788 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.23728813559322035 Test Loss: 1.7833291292190552 Learning rate: 0.001
# epochs: 30 Training/Validation loss: 1.6903177920509787 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.22033898305084745 Test Loss: 1.7728206813335419 Learning rate: 0.001
# epochs: 31 Training/Validation loss: 1.6871768727022058 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.2033898305084746 Test Loss: 1.7609226405620575 Learning rate: 0.001
# epochs: 32 Training/Validation loss: 1.6363410528968363 Training/Validation Accuracy: 0.22388059701492538 Test Accuracy: 0.22033898305084745 Test Loss: 1.7170871198177338 Learning rate: 0.001
# epochs: 33 Training/Validation loss: 1.701476770288804 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.2711864406779661 Test Loss: 1.70412278175354 Learning rate: 0.001
# epochs: 34 Training/Validation loss: 1.6482741552240707 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.288135593220339 Test Loss: 1.7191924452781677 Learning rate: 0.001
# epochs: 35 Training/Validation loss: 1.6741663498037003 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.22033898305084745 Test Loss: 1.7463482022285461 Learning rate: 0.001
# epochs: 36 Training/Validation loss: 1.6686457325430477 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.3220338983050847 Test Loss: 1.7157185971736908 Learning rate: 0.001
# epochs: 37 Training/Validation loss: 1.6695781595566694 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.288135593220339 Test Loss: 1.7326550483703613 Learning rate: 0.001
# epochs: 38 Training/Validation loss: 1.7002129835240982 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.23728813559322035 Test Loss: 1.714407354593277 Learning rate: 0.001
# epochs: 39 Training/Validation loss: 1.6967913192861221 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.2711864406779661 Test Loss: 1.7345094680786133 Learning rate: 0.001
# epochs: 40 Training/Validation loss: 1.6722601161283606 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.2542372881355932 Test Loss: 1.7634187936782837 Learning rate: 0.001
# epochs: 41 Training/Validation loss: 1.6879648250692032 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.2033898305084746 Test Loss: 1.7513800859451294 Learning rate: 0.001
# epochs: 42 Training/Validation loss: 1.6736507415771484 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.2542372881355932 Test Loss: 1.7530882060527802 Learning rate: 0.001
# epochs: 43 Training/Validation loss: 1.6835569844526403 Training/Validation Accuracy: 0.3582089552238806 Test Accuracy: 0.1694915254237288 Test Loss: 1.7934870421886444 Learning rate: 0.001
# epochs: 44 Training/Validation loss: 1.6868154020870434 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.2033898305084746 Test Loss: 1.708795428276062 Learning rate: 0.001
# epochs: 45 Training/Validation loss: 1.695169960751253 Training/Validation Accuracy: 0.1791044776119403 Test Accuracy: 0.22033898305084745 Test Loss: 1.73414745926857 Learning rate: 0.001
# epochs: 46 Training/Validation loss: 1.6760640074225033 Training/Validation Accuracy: 0.14925373134328357 Test Accuracy: 0.2542372881355932 Test Loss: 1.7490120828151703 Learning rate: 0.001
# epochs: 47 Training/Validation loss: 1.6833694121416878 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.3050847457627119 Test Loss: 1.7487232387065887 Learning rate: 0.001
# epochs: 48 Training/Validation loss: 1.6842148864970488 Training/Validation Accuracy: 0.208955223880597 Test Accuracy: 0.2033898305084746 Test Loss: 1.7213817536830902 Learning rate: 0.001
# epochs: 49 Training/Validation loss: 1.6738805069642908 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.1016949152542373 Test Loss: 1.7697435915470123 Learning rate: 0.001
# Time: 500 Maximum Test Accuracy: 0.3220338983050847 Minimum Valid Loss: 1
# 750
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 40, 22, 741]             440
#        BatchNorm2d-2          [-1, 40, 22, 741]              80
#               ReLU-3          [-1, 40, 22, 741]               0
#             Conv2d-4           [-1, 40, 1, 741]          35,240
#        BatchNorm2d-5           [-1, 40, 1, 741]              80
#               ReLU-6           [-1, 40, 1, 741]               0
#          AvgPool2d-7            [-1, 40, 1, 45]               0
#            Flatten-8                 [-1, 1800]               0
#            Dropout-9                 [-1, 1800]               0
#            Linear-10                    [-1, 4]           7,204
# ================================================================
# Total params: 43,044
# Trainable params: 43,044
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.06
# Forward/backward pass size (MB): 15.64
# Params size (MB): 0.16
# Estimated Total Size (MB): 15.87
# ----------------------------------------------------------------
# epochs: 0 Training/Validation loss: 1.6105288056766285 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.288135593220339 Test Loss: 1.6096389293670654 Learning rate: 0.001
# epochs: 1 Training/Validation loss: 1.6170504443785723 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.2711864406779661 Test Loss: 1.5698932111263275 Learning rate: 0.001
# epochs: 2 Training/Validation loss: 1.5947739727356856 Training/Validation Accuracy: 0.3283582089552239 Test Accuracy: 0.3389830508474576 Test Loss: 1.591378778219223 Learning rate: 0.001
# epochs: 3 Training/Validation loss: 1.6081930959925932 Training/Validation Accuracy: 0.19402985074626866 Test Accuracy: 0.3220338983050847 Test Loss: 1.5603982210159302 Learning rate: 0.001
# epochs: 4 Training/Validation loss: 1.6336312223883236 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.3389830508474576 Test Loss: 1.590486764907837 Learning rate: 0.001
# epochs: 5 Training/Validation loss: 1.6048969240749584 Training/Validation Accuracy: 0.19402985074626866 Test Accuracy: 0.288135593220339 Test Loss: 1.5550104677677155 Learning rate: 0.001
# epochs: 6 Training/Validation loss: 1.6088433405932259 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.288135593220339 Test Loss: 1.600368857383728 Learning rate: 0.001
# epochs: 7 Training/Validation loss: 1.6036851546343636 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.2711864406779661 Test Loss: 1.5836342573165894 Learning rate: 0.001
# epochs: 8 Training/Validation loss: 1.6011333956437952 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.3559322033898305 Test Loss: 1.563824087381363 Learning rate: 0.001
# epochs: 9 Training/Validation loss: 1.6125611838172464 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.2711864406779661 Test Loss: 1.6019920408725739 Learning rate: 0.001
# epochs: 10 Training/Validation loss: 1.603725875125212 Training/Validation Accuracy: 0.1791044776119403 Test Accuracy: 0.288135593220339 Test Loss: 1.585795521736145 Learning rate: 0.001
# epochs: 11 Training/Validation loss: 1.6109366136438705 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.2542372881355932 Test Loss: 1.6310487389564514 Learning rate: 0.001
# epochs: 12 Training/Validation loss: 1.6010484274695902 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.2711864406779661 Test Loss: 1.5914707481861115 Learning rate: 0.001
# epochs: 13 Training/Validation loss: 1.5832486222772038 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.3050847457627119 Test Loss: 1.5512301325798035 Learning rate: 0.001
# epochs: 14 Training/Validation loss: 1.6077346871880924 Training/Validation Accuracy: 0.3283582089552239 Test Accuracy: 0.15254237288135594 Test Loss: 1.6270571053028107 Learning rate: 0.001
# epochs: 15 Training/Validation loss: 1.6323741113438326 Training/Validation Accuracy: 0.208955223880597 Test Accuracy: 0.2542372881355932 Test Loss: 1.6092692613601685 Learning rate: 0.001
# epochs: 16 Training/Validation loss: 1.6227462502086865 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.2542372881355932 Test Loss: 1.595095455646515 Learning rate: 0.001
# epochs: 17 Training/Validation loss: 1.6215443821514355 Training/Validation Accuracy: 0.19402985074626866 Test Accuracy: 0.3220338983050847 Test Loss: 1.602386236190796 Learning rate: 0.001
# epochs: 18 Training/Validation loss: 1.612500548362732 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.3220338983050847 Test Loss: 1.5832130014896393 Learning rate: 0.001
# epochs: 19 Training/Validation loss: 1.6044499733868767 Training/Validation Accuracy: 0.34328358208955223 Test Accuracy: 0.288135593220339 Test Loss: 1.6316812932491302 Learning rate: 0.001
# epochs: 20 Training/Validation loss: 1.6045318912057316 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.3389830508474576 Test Loss: 1.5442724227905273 Learning rate: 0.001
# epochs: 21 Training/Validation loss: 1.6300429596620447 Training/Validation Accuracy: 0.208955223880597 Test Accuracy: 0.3220338983050847 Test Loss: 1.5724654495716095 Learning rate: 0.001
# epochs: 22 Training/Validation loss: 1.6083378511316635 Training/Validation Accuracy: 0.3582089552238806 Test Accuracy: 0.288135593220339 Test Loss: 1.5824231207370758 Learning rate: 0.001
# epochs: 23 Training/Validation loss: 1.6094743854859297 Training/Validation Accuracy: 0.3880597014925373 Test Accuracy: 0.2542372881355932 Test Loss: 1.5512599050998688 Learning rate: 0.001
# epochs: 24 Training/Validation loss: 1.623352191027473 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.2711864406779661 Test Loss: 1.6006464958190918 Learning rate: 0.001
# epochs: 25 Training/Validation loss: 1.6228457549039055 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.22033898305084745 Test Loss: 1.5747168362140656 Learning rate: 0.001
# epochs: 26 Training/Validation loss: 1.5873074812047623 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.3220338983050847 Test Loss: 1.5705526471138 Learning rate: 0.001
# epochs: 27 Training/Validation loss: 1.6308806503520292 Training/Validation Accuracy: 0.34328358208955223 Test Accuracy: 0.1694915254237288 Test Loss: 1.6511825323104858 Learning rate: 0.001
# epochs: 28 Training/Validation loss: 1.5988560283885282 Training/Validation Accuracy: 0.208955223880597 Test Accuracy: 0.1694915254237288 Test Loss: 1.616642326116562 Learning rate: 0.001
# epochs: 29 Training/Validation loss: 1.6383467632181503 Training/Validation Accuracy: 0.22388059701492538 Test Accuracy: 0.2711864406779661 Test Loss: 1.5606846809387207 Learning rate: 0.001
# epochs: 30 Training/Validation loss: 1.6132165053311516 Training/Validation Accuracy: 0.22388059701492538 Test Accuracy: 0.288135593220339 Test Loss: 1.569126009941101 Learning rate: 0.001
# epochs: 31 Training/Validation loss: 1.599160811480354 Training/Validation Accuracy: 0.19402985074626866 Test Accuracy: 0.288135593220339 Test Loss: 1.5743564367294312 Learning rate: 0.001
# epochs: 32 Training/Validation loss: 1.604836295632755 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.288135593220339 Test Loss: 1.5787465572357178 Learning rate: 0.001
# epochs: 33 Training/Validation loss: 1.61985085291021 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.3389830508474576 Test Loss: 1.557704895734787 Learning rate: 0.001
# epochs: 34 Training/Validation loss: 1.602195746758405 Training/Validation Accuracy: 0.22388059701492538 Test Accuracy: 0.1864406779661017 Test Loss: 1.640663981437683 Learning rate: 0.001
# epochs: 35 Training/Validation loss: 1.6161220143823063 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.4067796610169492 Test Loss: 1.5443452894687653 Learning rate: 0.001
# epochs: 36 Training/Validation loss: 1.60719395385069 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.3050847457627119 Test Loss: 1.6144806146621704 Learning rate: 0.001
# epochs: 37 Training/Validation loss: 1.614739361931296 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.3389830508474576 Test Loss: 1.5731975734233856 Learning rate: 0.001
# epochs: 38 Training/Validation loss: 1.6048345495672787 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.1694915254237288 Test Loss: 1.6049980223178864 Learning rate: 0.001
# epochs: 39 Training/Validation loss: 1.5998617761275347 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.23728813559322035 Test Loss: 1.5512653291225433 Learning rate: 0.001
# epochs: 40 Training/Validation loss: 1.6174241514766918 Training/Validation Accuracy: 0.3283582089552239 Test Accuracy: 0.22033898305084745 Test Loss: 1.627290815114975 Learning rate: 0.001
# epochs: 41 Training/Validation loss: 1.6113805069642908 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.23728813559322035 Test Loss: 1.6418780982494354 Learning rate: 0.001
# epochs: 42 Training/Validation loss: 1.5962730365640976 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.2711864406779661 Test Loss: 1.5972912907600403 Learning rate: 0.001
# epochs: 43 Training/Validation loss: 1.606522560119629 Training/Validation Accuracy: 0.3582089552238806 Test Accuracy: 0.22033898305084745 Test Loss: 1.5876899063587189 Learning rate: 0.001
# epochs: 44 Training/Validation loss: 1.5954275692210478 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.2033898305084746 Test Loss: 1.5844899117946625 Learning rate: 0.001
# epochs: 45 Training/Validation loss: 1.6317328144522274 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.288135593220339 Test Loss: 1.6135996282100677 Learning rate: 0.001
# epochs: 46 Training/Validation loss: 1.634582288124982 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.2711864406779661 Test Loss: 1.6052188873291016 Learning rate: 0.001
# epochs: 47 Training/Validation loss: 1.5891048627741196 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.22033898305084745 Test Loss: 1.5656754076480865 Learning rate: 0.001
# epochs: 48 Training/Validation loss: 1.6131369436488432 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.22033898305084745 Test Loss: 1.618927150964737 Learning rate: 0.001
# epochs: 49 Training/Validation loss: 1.589029024629032 Training/Validation Accuracy: 0.3880597014925373 Test Accuracy: 0.288135593220339 Test Loss: 1.5787065625190735 Learning rate: 0.001
# Time: 750 Maximum Test Accuracy: 0.4067796610169492 Minimum Valid Loss: 1
# 1000
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 40, 22, 991]             440
#        BatchNorm2d-2          [-1, 40, 22, 991]              80
#               ReLU-3          [-1, 40, 22, 991]               0
#             Conv2d-4           [-1, 40, 1, 991]          35,240
#        BatchNorm2d-5           [-1, 40, 1, 991]              80
#               ReLU-6           [-1, 40, 1, 991]               0
#          AvgPool2d-7            [-1, 40, 1, 62]               0
#            Flatten-8                 [-1, 2480]               0
#            Dropout-9                 [-1, 2480]               0
#            Linear-10                    [-1, 4]           9,924
# ================================================================
# Total params: 45,764
# Trainable params: 45,764
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.08
# Forward/backward pass size (MB): 20.92
# Params size (MB): 0.17
# Estimated Total Size (MB): 21.18
# ----------------------------------------------------------------
# epochs: 0 Training/Validation loss: 1.68927142199348 Training/Validation Accuracy: 0.1791044776119403 Test Accuracy: 0.15254237288135594 Test Loss: 1.7328756153583527 Learning rate: 0.001
# epochs: 1 Training/Validation loss: 1.6965053572374231 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.3050847457627119 Test Loss: 1.7524992227554321 Learning rate: 0.001
# epochs: 2 Training/Validation loss: 1.706177129464991 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.2542372881355932 Test Loss: 1.710389882326126 Learning rate: 0.001
# epochs: 3 Training/Validation loss: 1.7201174637850594 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.3050847457627119 Test Loss: 1.7020071744918823 Learning rate: 0.001
# epochs: 4 Training/Validation loss: 1.6965976041906021 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.2711864406779661 Test Loss: 1.7707158327102661 Learning rate: 0.001
# epochs: 5 Training/Validation loss: 1.7015915197484635 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.3050847457627119 Test Loss: 1.7108397781848907 Learning rate: 0.001
# epochs: 6 Training/Validation loss: 1.7109165121527279 Training/Validation Accuracy: 0.16417910447761194 Test Accuracy: 0.23728813559322035 Test Loss: 1.74843031167984 Learning rate: 0.001
# epochs: 7 Training/Validation loss: 1.6992976945989273 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.288135593220339 Test Loss: 1.6969619989395142 Learning rate: 0.001
# epochs: 8 Training/Validation loss: 1.69814554382773 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.2711864406779661 Test Loss: 1.6805552542209625 Learning rate: 0.001
# epochs: 9 Training/Validation loss: 1.6703150132123161 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.15254237288135594 Test Loss: 1.7167417705059052 Learning rate: 0.001
# epochs: 10 Training/Validation loss: 1.7102747173870312 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.1694915254237288 Test Loss: 1.764637529850006 Learning rate: 0.001
# epochs: 11 Training/Validation loss: 1.7114039519253899 Training/Validation Accuracy: 0.19402985074626866 Test Accuracy: 0.3220338983050847 Test Loss: 1.6961202025413513 Learning rate: 0.001
# epochs: 12 Training/Validation loss: 1.7081043229383581 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.1864406779661017 Test Loss: 1.7331459522247314 Learning rate: 0.001
# epochs: 13 Training/Validation loss: 1.7014668478685266 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.3050847457627119 Test Loss: 1.7728171646595001 Learning rate: 0.001
# epochs: 14 Training/Validation loss: 1.7128048784592573 Training/Validation Accuracy: 0.22388059701492538 Test Accuracy: 0.2711864406779661 Test Loss: 1.735954761505127 Learning rate: 0.001
# epochs: 15 Training/Validation loss: 1.6984024678959566 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.22033898305084745 Test Loss: 1.7871496081352234 Learning rate: 0.001
# epochs: 16 Training/Validation loss: 1.695272214272443 Training/Validation Accuracy: 0.34328358208955223 Test Accuracy: 0.2711864406779661 Test Loss: 1.7328231632709503 Learning rate: 0.001
# epochs: 17 Training/Validation loss: 1.690200602307039 Training/Validation Accuracy: 0.16417910447761194 Test Accuracy: 0.1864406779661017 Test Loss: 1.8072127997875214 Learning rate: 0.001
# epochs: 18 Training/Validation loss: 1.7168306603151209 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.2033898305084746 Test Loss: 1.7209539413452148 Learning rate: 0.001
# epochs: 19 Training/Validation loss: 1.7296116071588852 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.23728813559322035 Test Loss: 1.7510473728179932 Learning rate: 0.001
# epochs: 20 Training/Validation loss: 1.7285205476424272 Training/Validation Accuracy: 0.1791044776119403 Test Accuracy: 0.22033898305084745 Test Loss: 1.7098883986473083 Learning rate: 0.001
# epochs: 21 Training/Validation loss: 1.6869236090603996 Training/Validation Accuracy: 0.34328358208955223 Test Accuracy: 0.1864406779661017 Test Loss: 1.7874886691570282 Learning rate: 0.001
# epochs: 22 Training/Validation loss: 1.6872712163364185 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.2711864406779661 Test Loss: 1.7326862812042236 Learning rate: 0.001
# epochs: 23 Training/Validation loss: 1.686470305218416 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.2542372881355932 Test Loss: 1.7522138953208923 Learning rate: 0.001
# epochs: 24 Training/Validation loss: 1.6937862143797033 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.22033898305084745 Test Loss: 1.7419923841953278 Learning rate: 0.001
# epochs: 25 Training/Validation loss: 1.6875147468903486 Training/Validation Accuracy: 0.3283582089552239 Test Accuracy: 0.23728813559322035 Test Loss: 1.7417504489421844 Learning rate: 0.001
# epochs: 26 Training/Validation loss: 1.692641153055079 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.288135593220339 Test Loss: 1.7515747249126434 Learning rate: 0.001
# epochs: 27 Training/Validation loss: 1.684804965468014 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.2711864406779661 Test Loss: 1.7388701438903809 Learning rate: 0.001
# epochs: 28 Training/Validation loss: 1.700028657913208 Training/Validation Accuracy: 0.208955223880597 Test Accuracy: 0.22033898305084745 Test Loss: 1.7447618246078491 Learning rate: 0.001
# epochs: 29 Training/Validation loss: 1.6940252079683191 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.23728813559322035 Test Loss: 1.7379437685012817 Learning rate: 0.001
# epochs: 30 Training/Validation loss: 1.7050284568001242 Training/Validation Accuracy: 0.3582089552238806 Test Accuracy: 0.2711864406779661 Test Loss: 1.7816216349601746 Learning rate: 0.001
# epochs: 31 Training/Validation loss: 1.6831053986268885 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.2711864406779661 Test Loss: 1.7427051365375519 Learning rate: 0.001
# epochs: 32 Training/Validation loss: 1.7138681131250717 Training/Validation Accuracy: 0.2537313432835821 Test Accuracy: 0.2033898305084746 Test Loss: 1.7370665669441223 Learning rate: 0.001
# epochs: 33 Training/Validation loss: 1.6955315014895271 Training/Validation Accuracy: 0.34328358208955223 Test Accuracy: 0.22033898305084745 Test Loss: 1.78118297457695 Learning rate: 0.001
# epochs: 34 Training/Validation loss: 1.7266247412737679 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.1864406779661017 Test Loss: 1.8162990510463715 Learning rate: 0.001
# epochs: 35 Training/Validation loss: 1.6996566688313204 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.2711864406779661 Test Loss: 1.7522006034851074 Learning rate: 0.001
# epochs: 36 Training/Validation loss: 1.7006788113537956 Training/Validation Accuracy: 0.417910447761194 Test Accuracy: 0.288135593220339 Test Loss: 1.718962162733078 Learning rate: 0.001
# epochs: 37 Training/Validation loss: 1.6951694418402279 Training/Validation Accuracy: 0.23880597014925373 Test Accuracy: 0.3050847457627119 Test Loss: 1.7646907269954681 Learning rate: 0.001
# epochs: 38 Training/Validation loss: 1.7110421517316032 Training/Validation Accuracy: 0.26865671641791045 Test Accuracy: 0.2033898305084746 Test Loss: 1.8173586428165436 Learning rate: 0.001
# epochs: 39 Training/Validation loss: 1.6966191109488993 Training/Validation Accuracy: 0.16417910447761194 Test Accuracy: 0.288135593220339 Test Loss: 1.7063977122306824 Learning rate: 0.001
# epochs: 40 Training/Validation loss: 1.698129885336932 Training/Validation Accuracy: 0.22388059701492538 Test Accuracy: 0.2542372881355932 Test Loss: 1.7591265738010406 Learning rate: 0.001
# epochs: 41 Training/Validation loss: 1.7089608557084028 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.1864406779661017 Test Loss: 1.7254731357097626 Learning rate: 0.001
# epochs: 42 Training/Validation loss: 1.6869657810996561 Training/Validation Accuracy: 0.208955223880597 Test Accuracy: 0.2711864406779661 Test Loss: 1.7783415019512177 Learning rate: 0.001
# epochs: 43 Training/Validation loss: 1.713675618171692 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.22033898305084745 Test Loss: 1.7697001993656158 Learning rate: 0.001
# epochs: 44 Training/Validation loss: 1.7092337748583626 Training/Validation Accuracy: 0.29850746268656714 Test Accuracy: 0.2033898305084746 Test Loss: 1.7190046906471252 Learning rate: 0.001
# epochs: 45 Training/Validation loss: 1.7085826887803919 Training/Validation Accuracy: 0.3283582089552239 Test Accuracy: 0.2033898305084746 Test Loss: 1.7744339108467102 Learning rate: 0.001
# epochs: 46 Training/Validation loss: 1.7178416182013119 Training/Validation Accuracy: 0.1791044776119403 Test Accuracy: 0.288135593220339 Test Loss: 1.7308050096035004 Learning rate: 0.001
# epochs: 47 Training/Validation loss: 1.6761661838082706 Training/Validation Accuracy: 0.2835820895522388 Test Accuracy: 0.1694915254237288 Test Loss: 1.80585378408432 Learning rate: 0.001
# epochs: 48 Training/Validation loss: 1.687034151133369 Training/Validation Accuracy: 0.31343283582089554 Test Accuracy: 0.13559322033898305 Test Loss: 1.6828214526176453 Learning rate: 0.001
# epochs: 49 Training/Validation loss: 1.7197596816455616 Training/Validation Accuracy: 0.3283582089552239 Test Accuracy: 0.23728813559322035 Test Loss: 1.7395849823951721 Learning rate: 0.001
# Time: 1000 Maximum Test Accuracy: 0.3220338983050847 Minimum Valid Loss: 1
# Train accuracies:
# [0.3880597014925373, 0.3582089552238806, 0.3880597014925373, 0.417910447761194]
# Test accuracies:
# [0.3728813559322034, 0.3220338983050847, 0.4067796610169492, 0.3220338983050847]
# The best accuracy is 0.407.
# The corresponding time period is 750.
